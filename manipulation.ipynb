# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from typing import Tuple

from utilities import plot_hist_discrete_feature, min_max_scale_column, categorize_column, COLORS

# %%
df = pd.read_csv("Premier_DataFrama.csv")

# %%
df.describe()
# Out:
#         Person ID      Gender         Age  Sleep Duration  Quality of Sleep  \
# count  374.000000  374.000000  374.000000      374.000000        374.000000
# mean   187.500000    0.494652   42.184492        7.132086          7.312834
# std    108.108742    0.500641    8.673133        0.795657          1.196956
# min      1.000000    0.000000   27.000000        5.800000          4.000000
# 25%     94.250000    0.000000   35.250000        6.400000          6.000000
# 50%    187.500000    0.000000   43.000000        7.200000          7.000000
# 75%    280.750000    1.000000   50.000000        7.800000          8.000000
# max    374.000000    1.000000   59.000000        8.500000          9.000000
#
#        Physical Activity Level  Stress Level  Heart Rate   Daily Steps  \
# count               374.000000    374.000000  374.000000    374.000000
# mean                 59.171123      5.385027   70.165775   6816.844920
# ...

# %%
plot_hist_discrete_feature(df, 'Stress Level', True, (12, 10), None, color= COLORS["PRETTY_BLUE"], align= 'center')

# %%
new_df = min_max_scale_column(df, 'Stress Level', 1, 9, add_noise=True, noise_factor=0.3, convert_to_int=True, inplace=False)

# %%
plot_hist_discrete_feature(new_df, 'Stress Level', True, (12, 10), None, color= COLORS["PRETTY_BLUE"], align= 'center')

# %%
int_bins = [0, 4, 7, 11]
categorial_labels = ['Not Stressed', 'Slighly Stressed', 'Stressed']

categorize_column(new_df, 'Stress Level', int_bins, categorial_labels, handle_nan=True, drop_original=True, inplace= True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       1 int_bins = [0, 4, 7, 11]
#       2 categorial_labels = ['Not Stressed', 'Slighly Stressed', 'Stressed']
# ----> 4 categorize_column(new_df, 'Stress Level', int_bins, categorial_labels, handle_nan=True, drop_original=True, inplace= True)
#
# TypeError: categorize_column() got an unexpected keyword argument 'drop_original'

# %%
new_df
# Out:
#      Person ID  Gender  Age  Sleep Duration  Quality of Sleep  \
# 0            1       0   27             6.1                 6
# 1            2       0   28             6.2                 6
# 2            3       0   28             6.2                 6
# 3            4       0   28             5.9                 4
# 4            5       0   28             5.9                 4
# ..         ...     ...  ...             ...               ...
# 369        370       1   59             8.1                 9
# 370        371       1   59             8.0                 9
# 371        372       1   59             8.1                 9
# 372        373       1   59             8.1                 9
# 373        374       1   59             8.1                 9
#
#      Physical Activity Level  Heart Rate  Daily Steps  Sleep Disorder  \
# 0                         42          77         4200             0.0
# 1                         60          75        10000             0.0
# ...
